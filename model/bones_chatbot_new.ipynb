# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %%
corpus_name = "movie-corpus"
corpus = os.path.join("/content/drive/MyDrive/Colab Notebooks/Chatterbones", corpus_name)
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'

# %%
def loadLinesAndConversations(fileName):
    lines = {}
    conversations = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj

            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj

    return lines, conversations


def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations.values():
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %%
datafile = os.path.join('/content/drive/MyDrive/Colab Notebooks/Chatterbones/working/', "formatted_movie_lines.txt")

delimiter = '\t'
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

lines = {}
conversations = {}
lines, conversations = loadLinesAndConversations(os.path.join(corpus, "utterances.jsonl"))

with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

def readVocs(datafile, corpus_name):
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    voc.trim(MIN_COUNT)
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        if keep_input and keep_output:
            keep_pairs.append(pair)

    return keep_pairs


pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches
# Out:
# input_variable: tensor([[  19,   19,   85,  365,  109],
#         [  69,   10,   17,   17,   50],
#         [  24,   19,    7,  468,   19],
#         [  25,    4,  937,  295,  759],
#         [   5,   24, 2678, 1004,   10],
#         [ 523,  265,   14,   14,    2],
#         [  84,   10,    2,    2,    0],
#         [  14,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 8, 7, 7, 6])
# target_variable: tensor([[  11,  104,   34,   26,   90],
#         [ 208,  227,   14, 4504,   66],
#         [ 135,   24,   85,  405,  261],
#         [  48,  246,   17,  104,  133],
#         [  14,  135,   79,   17,  158],
#         [   2,   44, 2678,    7, 2077],
#         [   0,  140,   14,   13,  380],
#         [   0,   14,    2,  289,   10],
#         [   0,    2,    0,   14,    2],
#         [   0,    0,    0,    2,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True, False,  True,  True],
#         [False, False, False,  True, False]])
# max_target_len: 10

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        embedded = self.embedding(input_seq)
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        outputs, hidden = self.gru(packed, hidden)
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        return outputs, hidden

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        attn_energies = attn_energies.t()

        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        rnn_output, hidden = self.gru(embedded, last_hidden)
        attn_weights = self.attn(rnn_output, encoder_outputs)
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        return output, hidden

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    lengths = lengths.to("cpu")

    loss = 0
    print_losses = []
    n_totals = 0

    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    decoder_hidden = encoder_hidden[:decoder.n_layers]

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            decoder_input = target_variable[t].view(1, -1)
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    loss.backward()

    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        for _ in range(max_length):
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        return all_tokens, all_scores

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    indexes_batch = [indexesFromSentence(voc, sentence)]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    tokens, scores = searcher(input_batch, lengths, max_length)
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %%
model_name = 'cb_model'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = None

# %%
if loadFilename:
    checkpoint = torch.load(loadFilename)
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 10000
print_every = 1
save_every = 500

encoder.train()
decoder.train()

print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration: 5001; Percent complete: 50.0%; Average loss: 2.5133
# Iteration: 5002; Percent complete: 50.0%; Average loss: 2.3026
# Iteration: 5003; Percent complete: 50.0%; Average loss: 2.4666
# Iteration: 5004; Percent complete: 50.0%; Average loss: 2.1503
# Iteration: 5005; Percent complete: 50.0%; Average loss: 2.3941
# Iteration: 5006; Percent complete: 50.1%; Average loss: 2.0935
# Iteration: 5007; Percent complete: 50.1%; Average loss: 2.4058
# Iteration: 5008; Percent complete: 50.1%; Average loss: 2.3841
# Iteration: 5009; Percent complete: 50.1%; Average loss: 2.3165
# Iteration: 5010; Percent complete: 50.1%; Average loss: 2.4172
# Iteration: 5011; Percent complete: 50.1%; Average loss: 1.9951
# Iteration: 5012; Percent complete: 50.1%; Average loss: 2.2928
# Iteration: 5013; Percent complete: 50.1%; Average loss: 2.3749
# Iteration: 5014; Percent complete: 50.1%; Average loss: 2.5199
# Iteration: 5015; Percent complete: 50.1%; Average loss: 2.4273
# Iteration: 5016; Percent complete: 50.2%; Average loss: 2.0338
# Iteration: 5017; Percent complete: 50.2%; Average loss: 2.3863
# Iteration: 5018; Percent complete: 50.2%; Average loss: 2.3337
# Iteration: 5019; Percent complete: 50.2%; Average loss: 2.4909
# Iteration: 5020; Percent complete: 50.2%; Average loss: 2.3407
# Iteration: 5021; Percent complete: 50.2%; Average loss: 2.3161
# Iteration: 5022; Percent complete: 50.2%; Average loss: 2.4364
# Iteration: 5023; Percent complete: 50.2%; Average loss: 2.3733
# Iteration: 5024; Percent complete: 50.2%; Average loss: 2.3895
# Iteration: 5025; Percent complete: 50.2%; Average loss: 2.5284
# Iteration: 5026; Percent complete: 50.3%; Average loss: 2.4552
# Iteration: 5027; Percent complete: 50.3%; Average loss: 2.4770
# Iteration: 5028; Percent complete: 50.3%; Average loss: 2.3141
# Iteration: 5029; Percent complete: 50.3%; Average loss: 2.1591
# Iteration: 5030; Percent complete: 50.3%; Average loss: 2.5512
# Iteration: 5031; Percent complete: 50.3%; Average loss: 2.2650
# Iteration: 5032; Percent complete: 50.3%; Average loss: 2.1739
# Iteration: 5033; Percent complete: 50.3%; Average loss: 2.3629
# Iteration: 5034; Percent complete: 50.3%; Average loss: 2.4494
# Iteration: 5035; Percent complete: 50.3%; Average loss: 2.1673
# Iteration: 5036; Percent complete: 50.4%; Average loss: 2.4523
# Iteration: 5037; Percent complete: 50.4%; Average loss: 2.3653
# Iteration: 5038; Percent complete: 50.4%; Average loss: 2.3293
# Iteration: 5039; Percent complete: 50.4%; Average loss: 2.2426
# Iteration: 5040; Percent complete: 50.4%; Average loss: 2.3211
# Iteration: 5041; Percent complete: 50.4%; Average loss: 2.2901
# Iteration: 5042; Percent complete: 50.4%; Average loss: 2.4615
# Iteration: 5043; Percent complete: 50.4%; Average loss: 2.3045
# Iteration: 5044; Percent complete: 50.4%; Average loss: 2.2115
# Iteration: 5045; Percent complete: 50.4%; Average loss: 2.4229
# Iteration: 5046; Percent complete: 50.5%; Average loss: 2.1989
# Iteration: 5047; Percent complete: 50.5%; Average loss: 2.3011
# Iteration: 5048; Percent complete: 50.5%; Average loss: 2.4098
# Iteration: 5049; Percent complete: 50.5%; Average loss: 2.2856
# Iteration: 5050; Percent complete: 50.5%; Average loss: 2.4175
# Iteration: 5051; Percent complete: 50.5%; Average loss: 2.3554
# Iteration: 5052; Percent complete: 50.5%; Average loss: 2.3860
# Iteration: 5053; Percent complete: 50.5%; Average loss: 2.1170
# Iteration: 5054; Percent complete: 50.5%; Average loss: 2.4258
# Iteration: 5055; Percent complete: 50.5%; Average loss: 2.2890
# Iteration: 5056; Percent complete: 50.6%; Average loss: 2.3528
# Iteration: 5057; Percent complete: 50.6%; Average loss: 2.3067
# Iteration: 5058; Percent complete: 50.6%; Average loss: 2.3126
# Iteration: 5059; Percent complete: 50.6%; Average loss: 2.2147
# Iteration: 5060; Percent complete: 50.6%; Average loss: 2.5264
# Iteration: 5061; Percent complete: 50.6%; Average loss: 2.5042
# Iteration: 5062; Percent complete: 50.6%; Average loss: 2.3955
# Iteration: 5063; Percent complete: 50.6%; Average loss: 2.3601
# Iteration: 5064; Percent complete: 50.6%; Average loss: 2.1118
# Iteration: 5065; Percent complete: 50.6%; Average loss: 2.2830
# Iteration: 5066; Percent complete: 50.7%; Average loss: 2.3410
# Iteration: 5067; Percent complete: 50.7%; Average loss: 2.1194
# Iteration: 5068; Percent complete: 50.7%; Average loss: 2.2533
# Iteration: 5069; Percent complete: 50.7%; Average loss: 2.3062
# Iteration: 5070; Percent complete: 50.7%; Average loss: 2.3587
# Iteration: 5071; Percent complete: 50.7%; Average loss: 2.3047
# Iteration: 5072; Percent complete: 50.7%; Average loss: 2.4885
# Iteration: 5073; Percent complete: 50.7%; Average loss: 2.5070
# Iteration: 5074; Percent complete: 50.7%; Average loss: 2.2398
# Iteration: 5075; Percent complete: 50.7%; Average loss: 2.1078
# Iteration: 5076; Percent complete: 50.8%; Average loss: 2.5204
# Iteration: 5077; Percent complete: 50.8%; Average loss: 2.2312
# Iteration: 5078; Percent complete: 50.8%; Average loss: 2.4590
# Iteration: 5079; Percent complete: 50.8%; Average loss: 2.2431
# Iteration: 5080; Percent complete: 50.8%; Average loss: 2.3641
# Iteration: 5081; Percent complete: 50.8%; Average loss: 2.3779
# Iteration: 5082; Percent complete: 50.8%; Average loss: 2.5372
# Iteration: 5083; Percent complete: 50.8%; Average loss: 2.1862
# Iteration: 5084; Percent complete: 50.8%; Average loss: 2.3232
# Iteration: 5085; Percent complete: 50.8%; Average loss: 2.5129
# Iteration: 5086; Percent complete: 50.9%; Average loss: 2.3354
# Iteration: 5087; Percent complete: 50.9%; Average loss: 2.2237
# Iteration: 5088; Percent complete: 50.9%; Average loss: 2.3863
# Iteration: 5089; Percent complete: 50.9%; Average loss: 2.3130
# Iteration: 5090; Percent complete: 50.9%; Average loss: 2.4226
# Iteration: 5091; Percent complete: 50.9%; Average loss: 2.2896
# Iteration: 5092; Percent complete: 50.9%; Average loss: 2.3764
# Iteration: 5093; Percent complete: 50.9%; Average loss: 2.4056
# Iteration: 5094; Percent complete: 50.9%; Average loss: 2.4464
# Iteration: 5095; Percent complete: 50.9%; Average loss: 2.0693
# Iteration: 5096; Percent complete: 51.0%; Average loss: 2.2493
# Iteration: 5097; Percent complete: 51.0%; Average loss: 2.2191
# Iteration: 5098; Percent complete: 51.0%; Average loss: 2.6424
# Iteration: 5099; Percent complete: 51.0%; Average loss: 2.1130
# Iteration: 5100; Percent complete: 51.0%; Average loss: 2.1536
# Iteration: 5101; Percent complete: 51.0%; Average loss: 2.3928
# Iteration: 5102; Percent complete: 51.0%; Average loss: 2.3757
# Iteration: 5103; Percent complete: 51.0%; Average loss: 2.4045
# Iteration: 5104; Percent complete: 51.0%; Average loss: 2.2556
# Iteration: 5105; Percent complete: 51.0%; Average loss: 2.2788
# Iteration: 5106; Percent complete: 51.1%; Average loss: 2.1396
# Iteration: 5107; Percent complete: 51.1%; Average loss: 2.4739
# Iteration: 5108; Percent complete: 51.1%; Average loss: 2.1434
# Iteration: 5109; Percent complete: 51.1%; Average loss: 2.4379
# Iteration: 5110; Percent complete: 51.1%; Average loss: 2.1893
# Iteration: 5111; Percent complete: 51.1%; Average loss: 2.1209
# Iteration: 5112; Percent complete: 51.1%; Average loss: 2.4353
# Iteration: 5113; Percent complete: 51.1%; Average loss: 2.5660
# Iteration: 5114; Percent complete: 51.1%; Average loss: 2.1855
# Iteration: 5115; Percent complete: 51.1%; Average loss: 2.3471
# Iteration: 5116; Percent complete: 51.2%; Average loss: 2.4358
# Iteration: 5117; Percent complete: 51.2%; Average loss: 2.3461
# Iteration: 5118; Percent complete: 51.2%; Average loss: 2.3418
# Iteration: 5119; Percent complete: 51.2%; Average loss: 2.6573
# Iteration: 5120; Percent complete: 51.2%; Average loss: 2.2928
# Iteration: 5121; Percent complete: 51.2%; Average loss: 2.3652
# Iteration: 5122; Percent complete: 51.2%; Average loss: 2.2014
# Iteration: 5123; Percent complete: 51.2%; Average loss: 2.3774
# Iteration: 5124; Percent complete: 51.2%; Average loss: 2.4690
# Iteration: 5125; Percent complete: 51.2%; Average loss: 2.4022
# Iteration: 5126; Percent complete: 51.3%; Average loss: 2.3806
# Iteration: 5127; Percent complete: 51.3%; Average loss: 2.2700
# Iteration: 5128; Percent complete: 51.3%; Average loss: 2.1034
# Iteration: 5129; Percent complete: 51.3%; Average loss: 2.4388
# Iteration: 5130; Percent complete: 51.3%; Average loss: 2.1896
# Iteration: 5131; Percent complete: 51.3%; Average loss: 2.2158
# Iteration: 5132; Percent complete: 51.3%; Average loss: 2.1515
# Iteration: 5133; Percent complete: 51.3%; Average loss: 2.3579
# Iteration: 5134; Percent complete: 51.3%; Average loss: 2.3160
# Iteration: 5135; Percent complete: 51.3%; Average loss: 2.2863
# Iteration: 5136; Percent complete: 51.4%; Average loss: 2.3182
# Iteration: 5137; Percent complete: 51.4%; Average loss: 2.2796
# Iteration: 5138; Percent complete: 51.4%; Average loss: 2.4411
# Iteration: 5139; Percent complete: 51.4%; Average loss: 2.4645
# Iteration: 5140; Percent complete: 51.4%; Average loss: 2.5629
# Iteration: 5141; Percent complete: 51.4%; Average loss: 2.6053
# Iteration: 5142; Percent complete: 51.4%; Average loss: 2.6255
# Iteration: 5143; Percent complete: 51.4%; Average loss: 2.4828
# Iteration: 5144; Percent complete: 51.4%; Average loss: 2.5013
# Iteration: 5145; Percent complete: 51.4%; Average loss: 2.4480
# Iteration: 5146; Percent complete: 51.5%; Average loss: 2.4279
# Iteration: 5147; Percent complete: 51.5%; Average loss: 2.4180
# Iteration: 5148; Percent complete: 51.5%; Average loss: 2.3295
# Iteration: 5149; Percent complete: 51.5%; Average loss: 2.3021
# Iteration: 5150; Percent complete: 51.5%; Average loss: 2.3013
# Iteration: 5151; Percent complete: 51.5%; Average loss: 2.1130
# Iteration: 5152; Percent complete: 51.5%; Average loss: 2.2437
# Iteration: 5153; Percent complete: 51.5%; Average loss: 2.4384
# Iteration: 5154; Percent complete: 51.5%; Average loss: 2.2799
# Iteration: 5155; Percent complete: 51.5%; Average loss: 2.3552
# Iteration: 5156; Percent complete: 51.6%; Average loss: 2.4507
# Iteration: 5157; Percent complete: 51.6%; Average loss: 2.3103
# Iteration: 5158; Percent complete: 51.6%; Average loss: 2.4053
# Iteration: 5159; Percent complete: 51.6%; Average loss: 2.4632
# Iteration: 5160; Percent complete: 51.6%; Average loss: 2.2132
# Iteration: 5161; Percent complete: 51.6%; Average loss: 2.4164
# Iteration: 5162; Percent complete: 51.6%; Average loss: 2.3648
# Iteration: 5163; Percent complete: 51.6%; Average loss: 2.3892
# Iteration: 5164; Percent complete: 51.6%; Average loss: 2.2415
# Iteration: 5165; Percent complete: 51.6%; Average loss: 2.1580
# Iteration: 5166; Percent complete: 51.7%; Average loss: 2.3013
# Iteration: 5167; Percent complete: 51.7%; Average loss: 2.3508
# Iteration: 5168; Percent complete: 51.7%; Average loss: 2.2353
# Iteration: 5169; Percent complete: 51.7%; Average loss: 2.3833
# Iteration: 5170; Percent complete: 51.7%; Average loss: 2.3137
# Iteration: 5171; Percent complete: 51.7%; Average loss: 2.4354
# Iteration: 5172; Percent complete: 51.7%; Average loss: 2.2409
# Iteration: 5173; Percent complete: 51.7%; Average loss: 2.2856
# Iteration: 5174; Percent complete: 51.7%; Average loss: 2.1895
# Iteration: 5175; Percent complete: 51.7%; Average loss: 2.1920
# Iteration: 5176; Percent complete: 51.8%; Average loss: 2.2231
# Iteration: 5177; Percent complete: 51.8%; Average loss: 2.3360
# Iteration: 5178; Percent complete: 51.8%; Average loss: 2.2926
# Iteration: 5179; Percent complete: 51.8%; Average loss: 2.2674
# Iteration: 5180; Percent complete: 51.8%; Average loss: 2.5734
# Iteration: 5181; Percent complete: 51.8%; Average loss: 2.5013
# Iteration: 5182; Percent complete: 51.8%; Average loss: 2.2778
# Iteration: 5183; Percent complete: 51.8%; Average loss: 2.1564
# Iteration: 5184; Percent complete: 51.8%; Average loss: 2.2804
# Iteration: 5185; Percent complete: 51.8%; Average loss: 2.0749
# Iteration: 5186; Percent complete: 51.9%; Average loss: 2.3448
# Iteration: 5187; Percent complete: 51.9%; Average loss: 2.2364
# Iteration: 5188; Percent complete: 51.9%; Average loss: 2.0929
# Iteration: 5189; Percent complete: 51.9%; Average loss: 2.6790
# Iteration: 5190; Percent complete: 51.9%; Average loss: 2.6710
# Iteration: 5191; Percent complete: 51.9%; Average loss: 2.3709
# Iteration: 5192; Percent complete: 51.9%; Average loss: 2.4777
# Iteration: 5193; Percent complete: 51.9%; Average loss: 2.2601
# Iteration: 5194; Percent complete: 51.9%; Average loss: 2.3622
# Iteration: 5195; Percent complete: 51.9%; Average loss: 2.5549
# Iteration: 5196; Percent complete: 52.0%; Average loss: 2.1846
# Iteration: 5197; Percent complete: 52.0%; Average loss: 2.1680
# Iteration: 5198; Percent complete: 52.0%; Average loss: 2.0245
# Iteration: 5199; Percent complete: 52.0%; Average loss: 2.4347
# Iteration: 5200; Percent complete: 52.0%; Average loss: 2.4601
# Iteration: 5201; Percent complete: 52.0%; Average loss: 2.2236
# Iteration: 5202; Percent complete: 52.0%; Average loss: 2.3615
# Iteration: 5203; Percent complete: 52.0%; Average loss: 2.4028
# Iteration: 5204; Percent complete: 52.0%; Average loss: 2.1100
# Iteration: 5205; Percent complete: 52.0%; Average loss: 2.2883
# Iteration: 5206; Percent complete: 52.1%; Average loss: 2.3472
# Iteration: 5207; Percent complete: 52.1%; Average loss: 2.1012
# Iteration: 5208; Percent complete: 52.1%; Average loss: 2.3563
# Iteration: 5209; Percent complete: 52.1%; Average loss: 2.3264
# Iteration: 5210; Percent complete: 52.1%; Average loss: 2.3753
# Iteration: 5211; Percent complete: 52.1%; Average loss: 2.2321
# Iteration: 5212; Percent complete: 52.1%; Average loss: 2.1030
# Iteration: 5213; Percent complete: 52.1%; Average loss: 2.1256
# Iteration: 5214; Percent complete: 52.1%; Average loss: 2.2740
# Iteration: 5215; Percent complete: 52.1%; Average loss: 2.2589
# Iteration: 5216; Percent complete: 52.2%; Average loss: 2.3141
# Iteration: 5217; Percent complete: 52.2%; Average loss: 2.4021
# Iteration: 5218; Percent complete: 52.2%; Average loss: 2.2401
# Iteration: 5219; Percent complete: 52.2%; Average loss: 2.2190
# Iteration: 5220; Percent complete: 52.2%; Average loss: 2.1503
# Iteration: 5221; Percent complete: 52.2%; Average loss: 2.2903
# Iteration: 5222; Percent complete: 52.2%; Average loss: 2.5724
# Iteration: 5223; Percent complete: 52.2%; Average loss: 2.3895
# Iteration: 5224; Percent complete: 52.2%; Average loss: 2.2369
# Iteration: 5225; Percent complete: 52.2%; Average loss: 2.2808
# Iteration: 5226; Percent complete: 52.3%; Average loss: 2.6127
# Iteration: 5227; Percent complete: 52.3%; Average loss: 2.3509
# Iteration: 5228; Percent complete: 52.3%; Average loss: 2.1969
# Iteration: 5229; Percent complete: 52.3%; Average loss: 2.1314
# Iteration: 5230; Percent complete: 52.3%; Average loss: 2.2448
# Iteration: 5231; Percent complete: 52.3%; Average loss: 2.0523
# Iteration: 5232; Percent complete: 52.3%; Average loss: 2.2068
# Iteration: 5233; Percent complete: 52.3%; Average loss: 2.2276
# Iteration: 5234; Percent complete: 52.3%; Average loss: 2.2091
# Iteration: 5235; Percent complete: 52.3%; Average loss: 2.5111
# Iteration: 5236; Percent complete: 52.4%; Average loss: 2.5007
# Iteration: 5237; Percent complete: 52.4%; Average loss: 2.2466
# Iteration: 5238; Percent complete: 52.4%; Average loss: 2.1355
# Iteration: 5239; Percent complete: 52.4%; Average loss: 2.5878
# Iteration: 5240; Percent complete: 52.4%; Average loss: 2.1819
# Iteration: 5241; Percent complete: 52.4%; Average loss: 2.3301
# Iteration: 5242; Percent complete: 52.4%; Average loss: 2.3296
# Iteration: 5243; Percent complete: 52.4%; Average loss: 2.1408
# Iteration: 5244; Percent complete: 52.4%; Average loss: 2.2778
# Iteration: 5245; Percent complete: 52.4%; Average loss: 2.2768
# Iteration: 5246; Percent complete: 52.5%; Average loss: 2.1586
# Iteration: 5247; Percent complete: 52.5%; Average loss: 2.4924
# Iteration: 5248; Percent complete: 52.5%; Average loss: 2.2511
# Iteration: 5249; Percent complete: 52.5%; Average loss: 2.4242
# Iteration: 5250; Percent complete: 52.5%; Average loss: 2.4199
# Iteration: 5251; Percent complete: 52.5%; Average loss: 2.1935
# Iteration: 5252; Percent complete: 52.5%; Average loss: 2.3675
# Iteration: 5253; Percent complete: 52.5%; Average loss: 2.6121
# Iteration: 5254; Percent complete: 52.5%; Average loss: 2.2449
# Iteration: 5255; Percent complete: 52.5%; Average loss: 2.1339
# Iteration: 5256; Percent complete: 52.6%; Average loss: 2.4246
# Iteration: 5257; Percent complete: 52.6%; Average loss: 2.4486
# Iteration: 5258; Percent complete: 52.6%; Average loss: 2.2963
# Iteration: 5259; Percent complete: 52.6%; Average loss: 1.9807
# Iteration: 5260; Percent complete: 52.6%; Average loss: 2.1265
# Iteration: 5261; Percent complete: 52.6%; Average loss: 2.2365
# Iteration: 5262; Percent complete: 52.6%; Average loss: 2.1860
# Iteration: 5263; Percent complete: 52.6%; Average loss: 2.2592
# Iteration: 5264; Percent complete: 52.6%; Average loss: 2.2525
# Iteration: 5265; Percent complete: 52.6%; Average loss: 2.1959
# Iteration: 5266; Percent complete: 52.7%; Average loss: 2.1299
# Iteration: 5267; Percent complete: 52.7%; Average loss: 2.4532
# Iteration: 5268; Percent complete: 52.7%; Average loss: 2.1679
# Iteration: 5269; Percent complete: 52.7%; Average loss: 2.1620
# Iteration: 5270; Percent complete: 52.7%; Average loss: 2.3243
# Iteration: 5271; Percent complete: 52.7%; Average loss: 2.3657
# Iteration: 5272; Percent complete: 52.7%; Average loss: 2.2655
# Iteration: 5273; Percent complete: 52.7%; Average loss: 2.2048
# Iteration: 5274; Percent complete: 52.7%; Average loss: 2.4208
# Iteration: 5275; Percent complete: 52.8%; Average loss: 2.2205
# Iteration: 5276; Percent complete: 52.8%; Average loss: 2.3191
# Iteration: 5277; Percent complete: 52.8%; Average loss: 2.1244
# Iteration: 5278; Percent complete: 52.8%; Average loss: 2.3771
# Iteration: 5279; Percent complete: 52.8%; Average loss: 2.2712
# Iteration: 5280; Percent complete: 52.8%; Average loss: 2.3577
# Iteration: 5281; Percent complete: 52.8%; Average loss: 2.0563
# Iteration: 5282; Percent complete: 52.8%; Average loss: 2.2739
# Iteration: 5283; Percent complete: 52.8%; Average loss: 2.2078
# Iteration: 5284; Percent complete: 52.8%; Average loss: 2.2445
# Iteration: 5285; Percent complete: 52.8%; Average loss: 2.3519
# Iteration: 5286; Percent complete: 52.9%; Average loss: 2.4204
# Iteration: 5287; Percent complete: 52.9%; Average loss: 2.0295
# Iteration: 5288; Percent complete: 52.9%; Average loss: 2.4491
# Iteration: 5289; Percent complete: 52.9%; Average loss: 2.1656
# Iteration: 5290; Percent complete: 52.9%; Average loss: 2.0446
# Iteration: 5291; Percent complete: 52.9%; Average loss: 2.3923
# Iteration: 5292; Percent complete: 52.9%; Average loss: 2.3997
# Iteration: 5293; Percent complete: 52.9%; Average loss: 2.2165
# Iteration: 5294; Percent complete: 52.9%; Average loss: 2.2299
# Iteration: 5295; Percent complete: 52.9%; Average loss: 2.2394
# Iteration: 5296; Percent complete: 53.0%; Average loss: 2.2495
# Iteration: 5297; Percent complete: 53.0%; Average loss: 2.1724
# Iteration: 5298; Percent complete: 53.0%; Average loss: 2.0822
# Iteration: 5299; Percent complete: 53.0%; Average loss: 2.3767
# Iteration: 5300; Percent complete: 53.0%; Average loss: 2.4643
# Iteration: 5301; Percent complete: 53.0%; Average loss: 2.2116
# Iteration: 5302; Percent complete: 53.0%; Average loss: 2.4088
# Iteration: 5303; Percent complete: 53.0%; Average loss: 2.2782
# Iteration: 5304; Percent complete: 53.0%; Average loss: 2.2455
# Iteration: 5305; Percent complete: 53.0%; Average loss: 2.3390
# Iteration: 5306; Percent complete: 53.1%; Average loss: 2.1112
# Iteration: 5307; Percent complete: 53.1%; Average loss: 2.3522
# Iteration: 5308; Percent complete: 53.1%; Average loss: 2.2199
# Iteration: 5309; Percent complete: 53.1%; Average loss: 2.1594
# Iteration: 5310; Percent complete: 53.1%; Average loss: 2.2188
# Iteration: 5311; Percent complete: 53.1%; Average loss: 2.1726
# Iteration: 5312; Percent complete: 53.1%; Average loss: 2.1678
# Iteration: 5313; Percent complete: 53.1%; Average loss: 2.4088
# Iteration: 5314; Percent complete: 53.1%; Average loss: 2.0881
# Iteration: 5315; Percent complete: 53.1%; Average loss: 2.0584
# Iteration: 5316; Percent complete: 53.2%; Average loss: 2.2409
# Iteration: 5317; Percent complete: 53.2%; Average loss: 2.1906
# Iteration: 5318; Percent complete: 53.2%; Average loss: 2.4550
# Iteration: 5319; Percent complete: 53.2%; Average loss: 2.2248
# Iteration: 5320; Percent complete: 53.2%; Average loss: 2.1988
# Iteration: 5321; Percent complete: 53.2%; Average loss: 2.2313
# Iteration: 5322; Percent complete: 53.2%; Average loss: 2.1962
# Iteration: 5323; Percent complete: 53.2%; Average loss: 2.0999
# Iteration: 5324; Percent complete: 53.2%; Average loss: 2.1640
# Iteration: 5325; Percent complete: 53.2%; Average loss: 2.5350
# Iteration: 5326; Percent complete: 53.3%; Average loss: 2.1096
# Iteration: 5327; Percent complete: 53.3%; Average loss: 2.4280
# Iteration: 5328; Percent complete: 53.3%; Average loss: 2.2407
# Iteration: 5329; Percent complete: 53.3%; Average loss: 2.2200
# Iteration: 5330; Percent complete: 53.3%; Average loss: 2.0763
# Iteration: 5331; Percent complete: 53.3%; Average loss: 2.1778
# Iteration: 5332; Percent complete: 53.3%; Average loss: 2.2702
# Iteration: 5333; Percent complete: 53.3%; Average loss: 2.1634
# Iteration: 5334; Percent complete: 53.3%; Average loss: 2.1787
# Iteration: 5335; Percent complete: 53.3%; Average loss: 2.4526
# Iteration: 5336; Percent complete: 53.4%; Average loss: 2.3630
# Iteration: 5337; Percent complete: 53.4%; Average loss: 2.0963
# Iteration: 5338; Percent complete: 53.4%; Average loss: 2.2635
# Iteration: 5339; Percent complete: 53.4%; Average loss: 2.3895
# Iteration: 5340; Percent complete: 53.4%; Average loss: 2.4808
# Iteration: 5341; Percent complete: 53.4%; Average loss: 2.4721
# Iteration: 5342; Percent complete: 53.4%; Average loss: 2.4045
# Iteration: 5343; Percent complete: 53.4%; Average loss: 2.3964
# Iteration: 5344; Percent complete: 53.4%; Average loss: 2.3191
# Iteration: 5345; Percent complete: 53.4%; Average loss: 2.0820
# Iteration: 5346; Percent complete: 53.5%; Average loss: 2.2507
# Iteration: 5347; Percent complete: 53.5%; Average loss: 2.2096
# Iteration: 5348; Percent complete: 53.5%; Average loss: 2.0579
# Iteration: 5349; Percent complete: 53.5%; Average loss: 2.1476
# Iteration: 5350; Percent complete: 53.5%; Average loss: 2.3666
# Iteration: 5351; Percent complete: 53.5%; Average loss: 2.2589
# Iteration: 5352; Percent complete: 53.5%; Average loss: 2.4371
# Iteration: 5353; Percent complete: 53.5%; Average loss: 2.4105
# Iteration: 5354; Percent complete: 53.5%; Average loss: 2.2442
# Iteration: 5355; Percent complete: 53.5%; Average loss: 2.1358
# Iteration: 5356; Percent complete: 53.6%; Average loss: 2.2376
# Iteration: 5357; Percent complete: 53.6%; Average loss: 2.2918
# Iteration: 5358; Percent complete: 53.6%; Average loss: 2.2878
# Iteration: 5359; Percent complete: 53.6%; Average loss: 2.2660
# Iteration: 5360; Percent complete: 53.6%; Average loss: 2.1389
# Iteration: 5361; Percent complete: 53.6%; Average loss: 2.3558
# Iteration: 5362; Percent complete: 53.6%; Average loss: 2.2483
# Iteration: 5363; Percent complete: 53.6%; Average loss: 2.2429
# Iteration: 5364; Percent complete: 53.6%; Average loss: 2.2814
# Iteration: 5365; Percent complete: 53.6%; Average loss: 2.1686
# Iteration: 5366; Percent complete: 53.7%; Average loss: 2.0277
# Iteration: 5367; Percent complete: 53.7%; Average loss: 2.2981
# Iteration: 5368; Percent complete: 53.7%; Average loss: 2.4108
# Iteration: 5369; Percent complete: 53.7%; Average loss: 2.2300
# Iteration: 5370; Percent complete: 53.7%; Average loss: 2.0827
# Iteration: 5371; Percent complete: 53.7%; Average loss: 2.3617
# Iteration: 5372; Percent complete: 53.7%; Average loss: 2.1836
# Iteration: 5373; Percent complete: 53.7%; Average loss: 2.1553
# Iteration: 5374; Percent complete: 53.7%; Average loss: 2.2314
# Iteration: 5375; Percent complete: 53.8%; Average loss: 2.2794
# Iteration: 5376; Percent complete: 53.8%; Average loss: 2.2424
# Iteration: 5377; Percent complete: 53.8%; Average loss: 2.3631
# Iteration: 5378; Percent complete: 53.8%; Average loss: 2.2900
# Iteration: 5379; Percent complete: 53.8%; Average loss: 2.3125
# Iteration: 5380; Percent complete: 53.8%; Average loss: 2.3071
# Iteration: 5381; Percent complete: 53.8%; Average loss: 2.1730
# Iteration: 5382; Percent complete: 53.8%; Average loss: 2.2133
# Iteration: 5383; Percent complete: 53.8%; Average loss: 2.2902
# Iteration: 5384; Percent complete: 53.8%; Average loss: 2.1074
# Iteration: 5385; Percent complete: 53.8%; Average loss: 2.3266
# Iteration: 5386; Percent complete: 53.9%; Average loss: 2.2444
# Iteration: 5387; Percent complete: 53.9%; Average loss: 2.0055
# Iteration: 5388; Percent complete: 53.9%; Average loss: 2.2408
# Iteration: 5389; Percent complete: 53.9%; Average loss: 2.4100
# Iteration: 5390; Percent complete: 53.9%; Average loss: 2.3673
# Iteration: 5391; Percent complete: 53.9%; Average loss: 2.2039
# Iteration: 5392; Percent complete: 53.9%; Average loss: 2.2945
# Iteration: 5393; Percent complete: 53.9%; Average loss: 2.3966
# Iteration: 5394; Percent complete: 53.9%; Average loss: 2.2291
# Iteration: 5395; Percent complete: 53.9%; Average loss: 2.2734
# Iteration: 5396; Percent complete: 54.0%; Average loss: 2.2775
# Iteration: 5397; Percent complete: 54.0%; Average loss: 2.3435
# Iteration: 5398; Percent complete: 54.0%; Average loss: 2.3119
# Iteration: 5399; Percent complete: 54.0%; Average loss: 2.3779
# Iteration: 5400; Percent complete: 54.0%; Average loss: 2.3562
# Iteration: 5401; Percent complete: 54.0%; Average loss: 2.2403
# Iteration: 5402; Percent complete: 54.0%; Average loss: 2.4504
# Iteration: 5403; Percent complete: 54.0%; Average loss: 2.1967
# Iteration: 5404; Percent complete: 54.0%; Average loss: 2.4077
# Iteration: 5405; Percent complete: 54.0%; Average loss: 2.3617
# Iteration: 5406; Percent complete: 54.1%; Average loss: 2.2116
# Iteration: 5407; Percent complete: 54.1%; Average loss: 2.0109
# Iteration: 5408; Percent complete: 54.1%; Average loss: 2.2303
# Iteration: 5409; Percent complete: 54.1%; Average loss: 2.3000
# Iteration: 5410; Percent complete: 54.1%; Average loss: 2.0536
# Iteration: 5411; Percent complete: 54.1%; Average loss: 2.1146
# Iteration: 5412; Percent complete: 54.1%; Average loss: 2.3089
# Iteration: 5413; Percent complete: 54.1%; Average loss: 2.1624
# Iteration: 5414; Percent complete: 54.1%; Average loss: 2.4969
# Iteration: 5415; Percent complete: 54.1%; Average loss: 2.0775
# Iteration: 5416; Percent complete: 54.2%; Average loss: 2.1570
# Iteration: 5417; Percent complete: 54.2%; Average loss: 2.1334
# Iteration: 5418; Percent complete: 54.2%; Average loss: 2.1171
# Iteration: 5419; Percent complete: 54.2%; Average loss: 2.0829
# Iteration: 5420; Percent complete: 54.2%; Average loss: 2.2649
# Iteration: 5421; Percent complete: 54.2%; Average loss: 2.0564
# Iteration: 5422; Percent complete: 54.2%; Average loss: 2.2741
# Iteration: 5423; Percent complete: 54.2%; Average loss: 2.2382
# Iteration: 5424; Percent complete: 54.2%; Average loss: 2.3368
# Iteration: 5425; Percent complete: 54.2%; Average loss: 2.3039
# Iteration: 5426; Percent complete: 54.3%; Average loss: 2.1508
# Iteration: 5427; Percent complete: 54.3%; Average loss: 2.5943
# Iteration: 5428; Percent complete: 54.3%; Average loss: 2.0870
# Iteration: 5429; Percent complete: 54.3%; Average loss: 2.1265
# Iteration: 5430; Percent complete: 54.3%; Average loss: 2.3095
# Iteration: 5431; Percent complete: 54.3%; Average loss: 2.1907
# Iteration: 5432; Percent complete: 54.3%; Average loss: 2.2937
# Iteration: 5433; Percent complete: 54.3%; Average loss: 2.1833
# Iteration: 5434; Percent complete: 54.3%; Average loss: 2.0182
# Iteration: 5435; Percent complete: 54.4%; Average loss: 2.2446
# Iteration: 5436; Percent complete: 54.4%; Average loss: 2.5069
# Iteration: 5437; Percent complete: 54.4%; Average loss: 2.2068
# Iteration: 5438; Percent complete: 54.4%; Average loss: 2.4301
# Iteration: 5439; Percent complete: 54.4%; Average loss: 2.2951
# Iteration: 5440; Percent complete: 54.4%; Average loss: 1.9444
# Iteration: 5441; Percent complete: 54.4%; Average loss: 2.0396
# Iteration: 5442; Percent complete: 54.4%; Average loss: 2.2271
# Iteration: 5443; Percent complete: 54.4%; Average loss: 2.2550
# Iteration: 5444; Percent complete: 54.4%; Average loss: 2.3192
# Iteration: 5445; Percent complete: 54.4%; Average loss: 2.1522
# Iteration: 5446; Percent complete: 54.5%; Average loss: 2.3139
# Iteration: 5447; Percent complete: 54.5%; Average loss: 2.1997
# Iteration: 5448; Percent complete: 54.5%; Average loss: 2.2904
# Iteration: 5449; Percent complete: 54.5%; Average loss: 2.3957
# Iteration: 5450; Percent complete: 54.5%; Average loss: 2.1617
# Iteration: 5451; Percent complete: 54.5%; Average loss: 2.1929
# Iteration: 5452; Percent complete: 54.5%; Average loss: 2.2865
# Iteration: 5453; Percent complete: 54.5%; Average loss: 2.4925
# Iteration: 5454; Percent complete: 54.5%; Average loss: 2.3407
# Iteration: 5455; Percent complete: 54.5%; Average loss: 2.1032
# Iteration: 5456; Percent complete: 54.6%; Average loss: 2.2284
# Iteration: 5457; Percent complete: 54.6%; Average loss: 2.3455
# Iteration: 5458; Percent complete: 54.6%; Average loss: 2.1155
# Iteration: 5459; Percent complete: 54.6%; Average loss: 2.0386
# Iteration: 5460; Percent complete: 54.6%; Average loss: 2.3667
# Iteration: 5461; Percent complete: 54.6%; Average loss: 2.2242
# Iteration: 5462; Percent complete: 54.6%; Average loss: 2.2023
# Iteration: 5463; Percent complete: 54.6%; Average loss: 2.2769
# Iteration: 5464; Percent complete: 54.6%; Average loss: 2.1685
# Iteration: 5465; Percent complete: 54.6%; Average loss: 2.0522
# Iteration: 5466; Percent complete: 54.7%; Average loss: 2.0724
# Iteration: 5467; Percent complete: 54.7%; Average loss: 2.2876
# Iteration: 5468; Percent complete: 54.7%; Average loss: 2.1890
# Iteration: 5469; Percent complete: 54.7%; Average loss: 2.1757
# Iteration: 5470; Percent complete: 54.7%; Average loss: 2.2044
# Iteration: 5471; Percent complete: 54.7%; Average loss: 2.0590
# Iteration: 5472; Percent complete: 54.7%; Average loss: 2.1419
# Iteration: 5473; Percent complete: 54.7%; Average loss: 2.3349
# Iteration: 5474; Percent complete: 54.7%; Average loss: 2.1678
# Iteration: 5475; Percent complete: 54.8%; Average loss: 2.0785
# Iteration: 5476; Percent complete: 54.8%; Average loss: 2.2070
# Iteration: 5477; Percent complete: 54.8%; Average loss: 2.1970
# Iteration: 5478; Percent complete: 54.8%; Average loss: 2.3158
# Iteration: 5479; Percent complete: 54.8%; Average loss: 2.1516
# Iteration: 5480; Percent complete: 54.8%; Average loss: 2.4651
# Iteration: 5481; Percent complete: 54.8%; Average loss: 2.3499
# Iteration: 5482; Percent complete: 54.8%; Average loss: 2.1138
# Iteration: 5483; Percent complete: 54.8%; Average loss: 2.3503
# Iteration: 5484; Percent complete: 54.8%; Average loss: 2.1509
# Iteration: 5485; Percent complete: 54.9%; Average loss: 2.0678
# Iteration: 5486; Percent complete: 54.9%; Average loss: 2.1578
# Iteration: 5487; Percent complete: 54.9%; Average loss: 2.0421
# Iteration: 5488; Percent complete: 54.9%; Average loss: 2.4390
# Iteration: 5489; Percent complete: 54.9%; Average loss: 2.0837
# Iteration: 5490; Percent complete: 54.9%; Average loss: 2.0333
# Iteration: 5491; Percent complete: 54.9%; Average loss: 2.0090
# Iteration: 5492; Percent complete: 54.9%; Average loss: 2.3456
# Iteration: 5493; Percent complete: 54.9%; Average loss: 2.1197
# Iteration: 5494; Percent complete: 54.9%; Average loss: 2.2001
# Iteration: 5495; Percent complete: 54.9%; Average loss: 2.2629
# Iteration: 5496; Percent complete: 55.0%; Average loss: 2.0989
# Iteration: 5497; Percent complete: 55.0%; Average loss: 2.2282
# Iteration: 5498; Percent complete: 55.0%; Average loss: 2.3959
# Iteration: 5499; Percent complete: 55.0%; Average loss: 2.3554
# Iteration: 5500; Percent complete: 55.0%; Average loss: 2.3979
# Iteration: 5501; Percent complete: 55.0%; Average loss: 2.1355
# Iteration: 5502; Percent complete: 55.0%; Average loss: 2.2281
# Iteration: 5503; Percent complete: 55.0%; Average loss: 2.2899
# Iteration: 5504; Percent complete: 55.0%; Average loss: 2.1965
# Iteration: 5505; Percent complete: 55.0%; Average loss: 2.1855
# Iteration: 5506; Percent complete: 55.1%; Average loss: 2.1449
# Iteration: 5507; Percent complete: 55.1%; Average loss: 1.9803
# Iteration: 5508; Percent complete: 55.1%; Average loss: 2.2091
# Iteration: 5509; Percent complete: 55.1%; Average loss: 2.0857
# Iteration: 5510; Percent complete: 55.1%; Average loss: 2.0600
# Iteration: 5511; Percent complete: 55.1%; Average loss: 2.1260
# Iteration: 5512; Percent complete: 55.1%; Average loss: 2.2774
# Iteration: 5513; Percent complete: 55.1%; Average loss: 2.3213
# Iteration: 5514; Percent complete: 55.1%; Average loss: 2.0456
# Iteration: 5515; Percent complete: 55.1%; Average loss: 2.1880
# Iteration: 5516; Percent complete: 55.2%; Average loss: 2.1655
# Iteration: 5517; Percent complete: 55.2%; Average loss: 2.1176
# Iteration: 5518; Percent complete: 55.2%; Average loss: 2.1015
# Iteration: 5519; Percent complete: 55.2%; Average loss: 2.4642
# Iteration: 5520; Percent complete: 55.2%; Average loss: 2.3114
# Iteration: 5521; Percent complete: 55.2%; Average loss: 2.1944
# Iteration: 5522; Percent complete: 55.2%; Average loss: 2.3406
# Iteration: 5523; Percent complete: 55.2%; Average loss: 2.3072
# Iteration: 5524; Percent complete: 55.2%; Average loss: 2.1502
# Iteration: 5525; Percent complete: 55.2%; Average loss: 2.3291
# Iteration: 5526; Percent complete: 55.3%; Average loss: 2.1942
# Iteration: 5527; Percent complete: 55.3%; Average loss: 2.4645
# Iteration: 5528; Percent complete: 55.3%; Average loss: 2.2172
# Iteration: 5529; Percent complete: 55.3%; Average loss: 2.0767
# Iteration: 5530; Percent complete: 55.3%; Average loss: 2.1680
# Iteration: 5531; Percent complete: 55.3%; Average loss: 2.1998
# Iteration: 5532; Percent complete: 55.3%; Average loss: 2.3765
# Iteration: 5533; Percent complete: 55.3%; Average loss: 2.0547
# Iteration: 5534; Percent complete: 55.3%; Average loss: 2.2610
# Iteration: 5535; Percent complete: 55.4%; Average loss: 2.1442
# Iteration: 5536; Percent complete: 55.4%; Average loss: 2.0625
# Iteration: 5537; Percent complete: 55.4%; Average loss: 2.3112
# Iteration: 5538; Percent complete: 55.4%; Average loss: 2.2939
# Iteration: 5539; Percent complete: 55.4%; Average loss: 2.1546
# Iteration: 5540; Percent complete: 55.4%; Average loss: 2.1900
# Iteration: 5541; Percent complete: 55.4%; Average loss: 2.3276
# Iteration: 5542; Percent complete: 55.4%; Average loss: 2.0932
# Iteration: 5543; Percent complete: 55.4%; Average loss: 2.3356
# Iteration: 5544; Percent complete: 55.4%; Average loss: 2.0771
# Iteration: 5545; Percent complete: 55.5%; Average loss: 2.1802
# Iteration: 5546; Percent complete: 55.5%; Average loss: 2.1669
# Iteration: 5547; Percent complete: 55.5%; Average loss: 2.2009
# Iteration: 5548; Percent complete: 55.5%; Average loss: 2.2640
# Iteration: 5549; Percent complete: 55.5%; Average loss: 2.0831
# Iteration: 5550; Percent complete: 55.5%; Average loss: 2.2804
# Iteration: 5551; Percent complete: 55.5%; Average loss: 2.2458
# Iteration: 5552; Percent complete: 55.5%; Average loss: 2.1779
# Iteration: 5553; Percent complete: 55.5%; Average loss: 2.1236
# Iteration: 5554; Percent complete: 55.5%; Average loss: 2.1437
# Iteration: 5555; Percent complete: 55.5%; Average loss: 2.2941
# Iteration: 5556; Percent complete: 55.6%; Average loss: 2.2684
# Iteration: 5557; Percent complete: 55.6%; Average loss: 2.2265
# Iteration: 5558; Percent complete: 55.6%; Average loss: 2.2481
# Iteration: 5559; Percent complete: 55.6%; Average loss: 2.4015
# Iteration: 5560; Percent complete: 55.6%; Average loss: 2.1781
# Iteration: 5561; Percent complete: 55.6%; Average loss: 2.2639
# Iteration: 5562; Percent complete: 55.6%; Average loss: 2.1782
# Iteration: 5563; Percent complete: 55.6%; Average loss: 2.2896
# Iteration: 5564; Percent complete: 55.6%; Average loss: 2.0834
# Iteration: 5565; Percent complete: 55.6%; Average loss: 2.3371
# Iteration: 5566; Percent complete: 55.7%; Average loss: 2.2356
# Iteration: 5567; Percent complete: 55.7%; Average loss: 2.2298
# Iteration: 5568; Percent complete: 55.7%; Average loss: 2.2420
# Iteration: 5569; Percent complete: 55.7%; Average loss: 1.9757
# Iteration: 5570; Percent complete: 55.7%; Average loss: 2.2165
# Iteration: 5571; Percent complete: 55.7%; Average loss: 2.2260
# Iteration: 5572; Percent complete: 55.7%; Average loss: 2.0520
# Iteration: 5573; Percent complete: 55.7%; Average loss: 2.1274
# Iteration: 5574; Percent complete: 55.7%; Average loss: 2.1681
# Iteration: 5575; Percent complete: 55.8%; Average loss: 2.3815
# Iteration: 5576; Percent complete: 55.8%; Average loss: 2.1034
# Iteration: 5577; Percent complete: 55.8%; Average loss: 2.2174
# Iteration: 5578; Percent complete: 55.8%; Average loss: 2.3272
# Iteration: 5579; Percent complete: 55.8%; Average loss: 2.2292
# Iteration: 5580; Percent complete: 55.8%; Average loss: 2.1464
# Iteration: 5581; Percent complete: 55.8%; Average loss: 2.0142
# Iteration: 5582; Percent complete: 55.8%; Average loss: 2.0331
# Iteration: 5583; Percent complete: 55.8%; Average loss: 1.8015
# Iteration: 5584; Percent complete: 55.8%; Average loss: 2.1684
# Iteration: 5585; Percent complete: 55.9%; Average loss: 2.3595
# Iteration: 5586; Percent complete: 55.9%; Average loss: 2.4276
# Iteration: 5587; Percent complete: 55.9%; Average loss: 2.3575
# Iteration: 5588; Percent complete: 55.9%; Average loss: 2.0839
# Iteration: 5589; Percent complete: 55.9%; Average loss: 2.3587
# Iteration: 5590; Percent complete: 55.9%; Average loss: 2.1190
# Iteration: 5591; Percent complete: 55.9%; Average loss: 2.2236
# Iteration: 5592; Percent complete: 55.9%; Average loss: 2.3440
# Iteration: 5593; Percent complete: 55.9%; Average loss: 2.1632
# Iteration: 5594; Percent complete: 55.9%; Average loss: 2.2740
# Iteration: 5595; Percent complete: 56.0%; Average loss: 2.1934
# Iteration: 5596; Percent complete: 56.0%; Average loss: 2.2668
# Iteration: 5597; Percent complete: 56.0%; Average loss: 2.2187
# Iteration: 5598; Percent complete: 56.0%; Average loss: 2.0853
# Iteration: 5599; Percent complete: 56.0%; Average loss: 2.0551
# Iteration: 5600; Percent complete: 56.0%; Average loss: 2.3893
# Iteration: 5601; Percent complete: 56.0%; Average loss: 2.2804
# Iteration: 5602; Percent complete: 56.0%; Average loss: 2.2639
# Iteration: 5603; Percent complete: 56.0%; Average loss: 1.9873
# Iteration: 5604; Percent complete: 56.0%; Average loss: 2.0060
# Iteration: 5605; Percent complete: 56.0%; Average loss: 2.2374
# Iteration: 5606; Percent complete: 56.1%; Average loss: 2.0254
# Iteration: 5607; Percent complete: 56.1%; Average loss: 1.9996
# Iteration: 5608; Percent complete: 56.1%; Average loss: 2.3198
# Iteration: 5609; Percent complete: 56.1%; Average loss: 2.1314
# Iteration: 5610; Percent complete: 56.1%; Average loss: 2.2848
# Iteration: 5611; Percent complete: 56.1%; Average loss: 2.2061
# Iteration: 5612; Percent complete: 56.1%; Average loss: 2.1706
# Iteration: 5613; Percent complete: 56.1%; Average loss: 2.0881
# Iteration: 5614; Percent complete: 56.1%; Average loss: 2.3349
# Iteration: 5615; Percent complete: 56.1%; Average loss: 2.0816
# Iteration: 5616; Percent complete: 56.2%; Average loss: 1.9306
# Iteration: 5617; Percent complete: 56.2%; Average loss: 2.3220
# Iteration: 5618; Percent complete: 56.2%; Average loss: 2.1673
# Iteration: 5619; Percent complete: 56.2%; Average loss: 2.1859
# Iteration: 5620; Percent complete: 56.2%; Average loss: 1.9712
# Iteration: 5621; Percent complete: 56.2%; Average loss: 2.3187
# Iteration: 5622; Percent complete: 56.2%; Average loss: 2.1184
# Iteration: 5623; Percent complete: 56.2%; Average loss: 1.9942
# Iteration: 5624; Percent complete: 56.2%; Average loss: 2.2897
# Iteration: 5625; Percent complete: 56.2%; Average loss: 2.1853
# Iteration: 5626; Percent complete: 56.3%; Average loss: 2.2589
# Iteration: 5627; Percent complete: 56.3%; Average loss: 2.0300
# Iteration: 5628; Percent complete: 56.3%; Average loss: 2.2060
# Iteration: 5629; Percent complete: 56.3%; Average loss: 2.0865
# Iteration: 5630; Percent complete: 56.3%; Average loss: 2.0580
# Iteration: 5631; Percent complete: 56.3%; Average loss: 2.0613
# Iteration: 5632; Percent complete: 56.3%; Average loss: 2.2054
# Iteration: 5633; Percent complete: 56.3%; Average loss: 2.4351
# Iteration: 5634; Percent complete: 56.3%; Average loss: 2.1626
# Iteration: 5635; Percent complete: 56.4%; Average loss: 2.2262
# Iteration: 5636; Percent complete: 56.4%; Average loss: 2.3171
# Iteration: 5637; Percent complete: 56.4%; Average loss: 2.0002
# Iteration: 5638; Percent complete: 56.4%; Average loss: 2.3291
# Iteration: 5639; Percent complete: 56.4%; Average loss: 2.0073
# Iteration: 5640; Percent complete: 56.4%; Average loss: 2.4497
# Iteration: 5641; Percent complete: 56.4%; Average loss: 2.2118
# Iteration: 5642; Percent complete: 56.4%; Average loss: 2.2779
# Iteration: 5643; Percent complete: 56.4%; Average loss: 2.3101
# Iteration: 5644; Percent complete: 56.4%; Average loss: 2.1673
# Iteration: 5645; Percent complete: 56.5%; Average loss: 1.9632
# Iteration: 5646; Percent complete: 56.5%; Average loss: 2.0865
# Iteration: 5647; Percent complete: 56.5%; Average loss: 2.1880
# Iteration: 5648; Percent complete: 56.5%; Average loss: 2.1031
# Iteration: 5649; Percent complete: 56.5%; Average loss: 2.3452
# Iteration: 5650; Percent complete: 56.5%; Average loss: 2.1917
# Iteration: 5651; Percent complete: 56.5%; Average loss: 2.1889
# Iteration: 5652; Percent complete: 56.5%; Average loss: 2.1523
# Iteration: 5653; Percent complete: 56.5%; Average loss: 2.2329
# Iteration: 5654; Percent complete: 56.5%; Average loss: 2.3139
# Iteration: 5655; Percent complete: 56.5%; Average loss: 2.0950
# Iteration: 5656; Percent complete: 56.6%; Average loss: 2.1333
# Iteration: 5657; Percent complete: 56.6%; Average loss: 2.2156
# Iteration: 5658; Percent complete: 56.6%; Average loss: 2.3200
# Iteration: 5659; Percent complete: 56.6%; Average loss: 1.9578
# Iteration: 5660; Percent complete: 56.6%; Average loss: 2.2667
# Iteration: 5661; Percent complete: 56.6%; Average loss: 2.1401
# Iteration: 5662; Percent complete: 56.6%; Average loss: 2.0444
# Iteration: 5663; Percent complete: 56.6%; Average loss: 2.2513
# Iteration: 5664; Percent complete: 56.6%; Average loss: 2.3230
# Iteration: 5665; Percent complete: 56.6%; Average loss: 2.0673
# Iteration: 5666; Percent complete: 56.7%; Average loss: 2.4358
# Iteration: 5667; Percent complete: 56.7%; Average loss: 2.5186
# Iteration: 5668; Percent complete: 56.7%; Average loss: 2.2743
# Iteration: 5669; Percent complete: 56.7%; Average loss: 1.9021
# Iteration: 5670; Percent complete: 56.7%; Average loss: 2.0809
# Iteration: 5671; Percent complete: 56.7%; Average loss: 2.2530
# Iteration: 5672; Percent complete: 56.7%; Average loss: 2.1828
# Iteration: 5673; Percent complete: 56.7%; Average loss: 2.0583
# Iteration: 5674; Percent complete: 56.7%; Average loss: 2.0792
# Iteration: 5675; Percent complete: 56.8%; Average loss: 2.2069
# Iteration: 5676; Percent complete: 56.8%; Average loss: 2.3320
# Iteration: 5677; Percent complete: 56.8%; Average loss: 1.9899
# Iteration: 5678; Percent complete: 56.8%; Average loss: 2.1718
# Iteration: 5679; Percent complete: 56.8%; Average loss: 1.9140
# Iteration: 5680; Percent complete: 56.8%; Average loss: 2.2000
# Iteration: 5681; Percent complete: 56.8%; Average loss: 2.3808
# Iteration: 5682; Percent complete: 56.8%; Average loss: 2.1110
# Iteration: 5683; Percent complete: 56.8%; Average loss: 2.1431
# Iteration: 5684; Percent complete: 56.8%; Average loss: 1.9372
# Iteration: 5685; Percent complete: 56.9%; Average loss: 2.1775
# Iteration: 5686; Percent complete: 56.9%; Average loss: 2.1976
# Iteration: 5687; Percent complete: 56.9%; Average loss: 2.2464
# Iteration: 5688; Percent complete: 56.9%; Average loss: 2.0839
# Iteration: 5689; Percent complete: 56.9%; Average loss: 2.2043
# Iteration: 5690; Percent complete: 56.9%; Average loss: 2.2693
# Iteration: 5691; Percent complete: 56.9%; Average loss: 2.1862
# Iteration: 5692; Percent complete: 56.9%; Average loss: 2.3049
# Iteration: 5693; Percent complete: 56.9%; Average loss: 2.0017
# Iteration: 5694; Percent complete: 56.9%; Average loss: 2.0433
# Iteration: 5695; Percent complete: 57.0%; Average loss: 2.1345
# Iteration: 5696; Percent complete: 57.0%; Average loss: 2.1388
# Iteration: 5697; Percent complete: 57.0%; Average loss: 2.2522
# Iteration: 5698; Percent complete: 57.0%; Average loss: 2.3172
# Iteration: 5699; Percent complete: 57.0%; Average loss: 2.3728
# Iteration: 5700; Percent complete: 57.0%; Average loss: 2.2844
# Iteration: 5701; Percent complete: 57.0%; Average loss: 2.0757
# Iteration: 5702; Percent complete: 57.0%; Average loss: 2.2090
# Iteration: 5703; Percent complete: 57.0%; Average loss: 2.3953
# Iteration: 5704; Percent complete: 57.0%; Average loss: 1.9092
# Iteration: 5705; Percent complete: 57.0%; Average loss: 2.1398
# Iteration: 5706; Percent complete: 57.1%; Average loss: 2.3721
# Iteration: 5707; Percent complete: 57.1%; Average loss: 2.5043
# Iteration: 5708; Percent complete: 57.1%; Average loss: 2.1587
# Iteration: 5709; Percent complete: 57.1%; Average loss: 2.2379
# Iteration: 5710; Percent complete: 57.1%; Average loss: 2.3102
# Iteration: 5711; Percent complete: 57.1%; Average loss: 1.9608
# Iteration: 5712; Percent complete: 57.1%; Average loss: 2.1427
# Iteration: 5713; Percent complete: 57.1%; Average loss: 1.9635
# Iteration: 5714; Percent complete: 57.1%; Average loss: 2.1721
# Iteration: 5715; Percent complete: 57.1%; Average loss: 2.0285
# Iteration: 5716; Percent complete: 57.2%; Average loss: 2.0880
# Iteration: 5717; Percent complete: 57.2%; Average loss: 2.0550
# Iteration: 5718; Percent complete: 57.2%; Average loss: 2.0664
# Iteration: 5719; Percent complete: 57.2%; Average loss: 2.2095
# Iteration: 5720; Percent complete: 57.2%; Average loss: 2.2249
# Iteration: 5721; Percent complete: 57.2%; Average loss: 2.1190
# Iteration: 5722; Percent complete: 57.2%; Average loss: 2.2997
# Iteration: 5723; Percent complete: 57.2%; Average loss: 2.2694
# Iteration: 5724; Percent complete: 57.2%; Average loss: 2.1420
# Iteration: 5725; Percent complete: 57.2%; Average loss: 2.0928
# Iteration: 5726; Percent complete: 57.3%; Average loss: 2.2606
# Iteration: 5727; Percent complete: 57.3%; Average loss: 2.2382
# Iteration: 5728; Percent complete: 57.3%; Average loss: 2.0651
# Iteration: 5729; Percent complete: 57.3%; Average loss: 2.1121
# Iteration: 5730; Percent complete: 57.3%; Average loss: 2.1577
# Iteration: 5731; Percent complete: 57.3%; Average loss: 2.2610
# Iteration: 5732; Percent complete: 57.3%; Average loss: 2.0975
# Iteration: 5733; Percent complete: 57.3%; Average loss: 2.0600
# Iteration: 5734; Percent complete: 57.3%; Average loss: 2.4130
# Iteration: 5735; Percent complete: 57.4%; Average loss: 2.3852
# Iteration: 5736; Percent complete: 57.4%; Average loss: 2.2409
# Iteration: 5737; Percent complete: 57.4%; Average loss: 2.3005
# Iteration: 5738; Percent complete: 57.4%; Average loss: 2.1447
# Iteration: 5739; Percent complete: 57.4%; Average loss: 2.2891
# Iteration: 5740; Percent complete: 57.4%; Average loss: 2.3530
# Iteration: 5741; Percent complete: 57.4%; Average loss: 2.2031
# Iteration: 5742; Percent complete: 57.4%; Average loss: 2.2327
# Iteration: 5743; Percent complete: 57.4%; Average loss: 2.4049
# Iteration: 5744; Percent complete: 57.4%; Average loss: 2.1415
# Iteration: 5745; Percent complete: 57.5%; Average loss: 2.3268
# Iteration: 5746; Percent complete: 57.5%; Average loss: 1.8526
# Iteration: 5747; Percent complete: 57.5%; Average loss: 2.2020
# Iteration: 5748; Percent complete: 57.5%; Average loss: 2.2354
# Iteration: 5749; Percent complete: 57.5%; Average loss: 2.4200
# Iteration: 5750; Percent complete: 57.5%; Average loss: 2.1762
# Iteration: 5751; Percent complete: 57.5%; Average loss: 2.2074
# Iteration: 5752; Percent complete: 57.5%; Average loss: 2.0640
# Iteration: 5753; Percent complete: 57.5%; Average loss: 1.9639
# Iteration: 5754; Percent complete: 57.5%; Average loss: 2.4395
# Iteration: 5755; Percent complete: 57.6%; Average loss: 2.1691
# Iteration: 5756; Percent complete: 57.6%; Average loss: 2.1194
# Iteration: 5757; Percent complete: 57.6%; Average loss: 2.1499
# Iteration: 5758; Percent complete: 57.6%; Average loss: 2.0092
# Iteration: 5759; Percent complete: 57.6%; Average loss: 2.1677
# Iteration: 5760; Percent complete: 57.6%; Average loss: 2.3472
# Iteration: 5761; Percent complete: 57.6%; Average loss: 2.1542
# ...
# Iteration: 9748; Percent complete: 97.5%; Average loss: 1.2841
# Iteration: 9749; Percent complete: 97.5%; Average loss: 1.4377
# Iteration: 9750; Percent complete: 97.5%; Average loss: 1.3610
# Iteration: 9751; Percent complete: 97.5%; Average loss: 1.2435
# Iteration: 9752; Percent complete: 97.5%; Average loss: 1.4207
# Iteration: 9753; Percent complete: 97.5%; Average loss: 1.5241
# Iteration: 9754; Percent complete: 97.5%; Average loss: 1.4095
# Iteration: 9755; Percent complete: 97.5%; Average loss: 1.4557
# Iteration: 9756; Percent complete: 97.6%; Average loss: 1.1515
# Iteration: 9757; Percent complete: 97.6%; Average loss: 1.5602
# Iteration: 9758; Percent complete: 97.6%; Average loss: 1.5299
# Iteration: 9759; Percent complete: 97.6%; Average loss: 1.2802
# Iteration: 9760; Percent complete: 97.6%; Average loss: 1.1209
# Iteration: 9761; Percent complete: 97.6%; Average loss: 1.2260
# Iteration: 9762; Percent complete: 97.6%; Average loss: 1.3877
# Iteration: 9763; Percent complete: 97.6%; Average loss: 1.2670
# Iteration: 9764; Percent complete: 97.6%; Average loss: 1.2628
# Iteration: 9765; Percent complete: 97.7%; Average loss: 1.3973
# Iteration: 9766; Percent complete: 97.7%; Average loss: 1.3535
# Iteration: 9767; Percent complete: 97.7%; Average loss: 1.3175
# Iteration: 9768; Percent complete: 97.7%; Average loss: 1.4275
# Iteration: 9769; Percent complete: 97.7%; Average loss: 1.4510
# Iteration: 9770; Percent complete: 97.7%; Average loss: 1.4333
# Iteration: 9771; Percent complete: 97.7%; Average loss: 1.3884
# Iteration: 9772; Percent complete: 97.7%; Average loss: 1.2535
# Iteration: 9773; Percent complete: 97.7%; Average loss: 1.6324
# Iteration: 9774; Percent complete: 97.7%; Average loss: 1.4041
# Iteration: 9775; Percent complete: 97.8%; Average loss: 1.3159
# Iteration: 9776; Percent complete: 97.8%; Average loss: 1.2451
# Iteration: 9777; Percent complete: 97.8%; Average loss: 1.4198
# Iteration: 9778; Percent complete: 97.8%; Average loss: 1.2224
# Iteration: 9779; Percent complete: 97.8%; Average loss: 1.3886
# Iteration: 9780; Percent complete: 97.8%; Average loss: 1.1925
# Iteration: 9781; Percent complete: 97.8%; Average loss: 1.4633
# Iteration: 9782; Percent complete: 97.8%; Average loss: 1.2447
# Iteration: 9783; Percent complete: 97.8%; Average loss: 1.3491
# Iteration: 9784; Percent complete: 97.8%; Average loss: 1.2219
# Iteration: 9785; Percent complete: 97.9%; Average loss: 1.5918
# Iteration: 9786; Percent complete: 97.9%; Average loss: 1.3622
# Iteration: 9787; Percent complete: 97.9%; Average loss: 1.3238
# Iteration: 9788; Percent complete: 97.9%; Average loss: 1.2108
# Iteration: 9789; Percent complete: 97.9%; Average loss: 1.1546
# Iteration: 9790; Percent complete: 97.9%; Average loss: 1.3395
# Iteration: 9791; Percent complete: 97.9%; Average loss: 1.2854
# Iteration: 9792; Percent complete: 97.9%; Average loss: 1.1868
# Iteration: 9793; Percent complete: 97.9%; Average loss: 1.3858
# Iteration: 9794; Percent complete: 97.9%; Average loss: 1.1541
# Iteration: 9795; Percent complete: 98.0%; Average loss: 1.3448
# Iteration: 9796; Percent complete: 98.0%; Average loss: 1.3747
# Iteration: 9797; Percent complete: 98.0%; Average loss: 1.4259
# Iteration: 9798; Percent complete: 98.0%; Average loss: 1.2680
# Iteration: 9799; Percent complete: 98.0%; Average loss: 1.1358
# Iteration: 9800; Percent complete: 98.0%; Average loss: 1.2104
# Iteration: 9801; Percent complete: 98.0%; Average loss: 1.3693
# Iteration: 9802; Percent complete: 98.0%; Average loss: 1.3117
# Iteration: 9803; Percent complete: 98.0%; Average loss: 1.3808
# Iteration: 9804; Percent complete: 98.0%; Average loss: 1.3299
# Iteration: 9805; Percent complete: 98.0%; Average loss: 1.5171
# Iteration: 9806; Percent complete: 98.1%; Average loss: 1.2913
# Iteration: 9807; Percent complete: 98.1%; Average loss: 1.3954
# Iteration: 9808; Percent complete: 98.1%; Average loss: 1.3402
# Iteration: 9809; Percent complete: 98.1%; Average loss: 1.5029
# Iteration: 9810; Percent complete: 98.1%; Average loss: 1.4515
# Iteration: 9811; Percent complete: 98.1%; Average loss: 1.2189
# Iteration: 9812; Percent complete: 98.1%; Average loss: 1.4746
# Iteration: 9813; Percent complete: 98.1%; Average loss: 1.2819
# Iteration: 9814; Percent complete: 98.1%; Average loss: 1.5195
# Iteration: 9815; Percent complete: 98.2%; Average loss: 1.1272
# Iteration: 9816; Percent complete: 98.2%; Average loss: 1.4605
# Iteration: 9817; Percent complete: 98.2%; Average loss: 1.3628
# Iteration: 9818; Percent complete: 98.2%; Average loss: 1.2152
# Iteration: 9819; Percent complete: 98.2%; Average loss: 1.2564
# Iteration: 9820; Percent complete: 98.2%; Average loss: 1.3783
# Iteration: 9821; Percent complete: 98.2%; Average loss: 1.2949
# Iteration: 9822; Percent complete: 98.2%; Average loss: 1.3825
# Iteration: 9823; Percent complete: 98.2%; Average loss: 1.2808
# Iteration: 9824; Percent complete: 98.2%; Average loss: 1.3027
# Iteration: 9825; Percent complete: 98.2%; Average loss: 1.3599
# Iteration: 9826; Percent complete: 98.3%; Average loss: 1.3572
# Iteration: 9827; Percent complete: 98.3%; Average loss: 1.3406
# Iteration: 9828; Percent complete: 98.3%; Average loss: 1.3019
# Iteration: 9829; Percent complete: 98.3%; Average loss: 1.4055
# Iteration: 9830; Percent complete: 98.3%; Average loss: 1.3246
# Iteration: 9831; Percent complete: 98.3%; Average loss: 1.6029
# Iteration: 9832; Percent complete: 98.3%; Average loss: 1.4205
# Iteration: 9833; Percent complete: 98.3%; Average loss: 1.5095
# Iteration: 9834; Percent complete: 98.3%; Average loss: 1.2779
# Iteration: 9835; Percent complete: 98.4%; Average loss: 1.4389
# Iteration: 9836; Percent complete: 98.4%; Average loss: 1.4105
# Iteration: 9837; Percent complete: 98.4%; Average loss: 1.4300
# Iteration: 9838; Percent complete: 98.4%; Average loss: 1.3560
# Iteration: 9839; Percent complete: 98.4%; Average loss: 1.2576
# Iteration: 9840; Percent complete: 98.4%; Average loss: 1.3223
# Iteration: 9841; Percent complete: 98.4%; Average loss: 1.4423
# Iteration: 9842; Percent complete: 98.4%; Average loss: 1.3224
# Iteration: 9843; Percent complete: 98.4%; Average loss: 1.2285
# Iteration: 9844; Percent complete: 98.4%; Average loss: 1.1425
# Iteration: 9845; Percent complete: 98.5%; Average loss: 1.3917
# Iteration: 9846; Percent complete: 98.5%; Average loss: 1.3814
# Iteration: 9847; Percent complete: 98.5%; Average loss: 1.4636
# Iteration: 9848; Percent complete: 98.5%; Average loss: 1.2245
# Iteration: 9849; Percent complete: 98.5%; Average loss: 1.1449
# Iteration: 9850; Percent complete: 98.5%; Average loss: 1.2127
# Iteration: 9851; Percent complete: 98.5%; Average loss: 1.3953
# Iteration: 9852; Percent complete: 98.5%; Average loss: 1.3371
# Iteration: 9853; Percent complete: 98.5%; Average loss: 1.2809
# Iteration: 9854; Percent complete: 98.5%; Average loss: 1.1770
# Iteration: 9855; Percent complete: 98.6%; Average loss: 1.2060
# Iteration: 9856; Percent complete: 98.6%; Average loss: 1.3490
# Iteration: 9857; Percent complete: 98.6%; Average loss: 1.3579
# Iteration: 9858; Percent complete: 98.6%; Average loss: 1.1724
# Iteration: 9859; Percent complete: 98.6%; Average loss: 1.4052
# Iteration: 9860; Percent complete: 98.6%; Average loss: 1.4937
# Iteration: 9861; Percent complete: 98.6%; Average loss: 1.1844
# Iteration: 9862; Percent complete: 98.6%; Average loss: 1.4477
# Iteration: 9863; Percent complete: 98.6%; Average loss: 1.2734
# Iteration: 9864; Percent complete: 98.6%; Average loss: 1.3555
# Iteration: 9865; Percent complete: 98.7%; Average loss: 1.0544
# Iteration: 9866; Percent complete: 98.7%; Average loss: 1.3847
# Iteration: 9867; Percent complete: 98.7%; Average loss: 1.2096
# Iteration: 9868; Percent complete: 98.7%; Average loss: 1.4746
# Iteration: 9869; Percent complete: 98.7%; Average loss: 1.4139
# Iteration: 9870; Percent complete: 98.7%; Average loss: 1.4100
# Iteration: 9871; Percent complete: 98.7%; Average loss: 1.3387
# Iteration: 9872; Percent complete: 98.7%; Average loss: 1.5876
# Iteration: 9873; Percent complete: 98.7%; Average loss: 1.4412
# Iteration: 9874; Percent complete: 98.7%; Average loss: 1.2338
# Iteration: 9875; Percent complete: 98.8%; Average loss: 1.4404
# Iteration: 9876; Percent complete: 98.8%; Average loss: 1.3404
# Iteration: 9877; Percent complete: 98.8%; Average loss: 1.3267
# Iteration: 9878; Percent complete: 98.8%; Average loss: 1.3826
# Iteration: 9879; Percent complete: 98.8%; Average loss: 1.4077
# Iteration: 9880; Percent complete: 98.8%; Average loss: 1.3011
# Iteration: 9881; Percent complete: 98.8%; Average loss: 1.3058
# Iteration: 9882; Percent complete: 98.8%; Average loss: 1.3445
# Iteration: 9883; Percent complete: 98.8%; Average loss: 1.2430
# Iteration: 9884; Percent complete: 98.8%; Average loss: 1.5041
# Iteration: 9885; Percent complete: 98.9%; Average loss: 1.1673
# Iteration: 9886; Percent complete: 98.9%; Average loss: 1.4220
# Iteration: 9887; Percent complete: 98.9%; Average loss: 1.2531
# Iteration: 9888; Percent complete: 98.9%; Average loss: 1.3828
# Iteration: 9889; Percent complete: 98.9%; Average loss: 1.1585
# Iteration: 9890; Percent complete: 98.9%; Average loss: 1.2755
# Iteration: 9891; Percent complete: 98.9%; Average loss: 1.2561
# Iteration: 9892; Percent complete: 98.9%; Average loss: 1.2546
# Iteration: 9893; Percent complete: 98.9%; Average loss: 1.1518
# Iteration: 9894; Percent complete: 98.9%; Average loss: 1.1570
# Iteration: 9895; Percent complete: 99.0%; Average loss: 1.2413
# Iteration: 9896; Percent complete: 99.0%; Average loss: 1.3654
# Iteration: 9897; Percent complete: 99.0%; Average loss: 1.4317
# Iteration: 9898; Percent complete: 99.0%; Average loss: 1.2654
# Iteration: 9899; Percent complete: 99.0%; Average loss: 1.4227
# Iteration: 9900; Percent complete: 99.0%; Average loss: 1.4114
# Iteration: 9901; Percent complete: 99.0%; Average loss: 1.3525
# Iteration: 9902; Percent complete: 99.0%; Average loss: 1.2600
# Iteration: 9903; Percent complete: 99.0%; Average loss: 1.3236
# Iteration: 9904; Percent complete: 99.0%; Average loss: 1.3117
# Iteration: 9905; Percent complete: 99.1%; Average loss: 1.2921
# Iteration: 9906; Percent complete: 99.1%; Average loss: 1.6120
# Iteration: 9907; Percent complete: 99.1%; Average loss: 1.3206
# Iteration: 9908; Percent complete: 99.1%; Average loss: 1.2985
# Iteration: 9909; Percent complete: 99.1%; Average loss: 1.3330
# Iteration: 9910; Percent complete: 99.1%; Average loss: 1.4657
# Iteration: 9911; Percent complete: 99.1%; Average loss: 1.3420
# Iteration: 9912; Percent complete: 99.1%; Average loss: 1.4513
# Iteration: 9913; Percent complete: 99.1%; Average loss: 1.2490
# Iteration: 9914; Percent complete: 99.1%; Average loss: 1.2839
# Iteration: 9915; Percent complete: 99.2%; Average loss: 1.2983
# Iteration: 9916; Percent complete: 99.2%; Average loss: 1.3859
# Iteration: 9917; Percent complete: 99.2%; Average loss: 1.3468
# Iteration: 9918; Percent complete: 99.2%; Average loss: 1.2306
# Iteration: 9919; Percent complete: 99.2%; Average loss: 1.2339
# Iteration: 9920; Percent complete: 99.2%; Average loss: 1.4210
# Iteration: 9921; Percent complete: 99.2%; Average loss: 1.1371
# Iteration: 9922; Percent complete: 99.2%; Average loss: 1.1143
# Iteration: 9923; Percent complete: 99.2%; Average loss: 1.2908
# Iteration: 9924; Percent complete: 99.2%; Average loss: 1.3956
# Iteration: 9925; Percent complete: 99.2%; Average loss: 1.1502
# Iteration: 9926; Percent complete: 99.3%; Average loss: 1.2461
# Iteration: 9927; Percent complete: 99.3%; Average loss: 1.3193
# Iteration: 9928; Percent complete: 99.3%; Average loss: 1.4604
# Iteration: 9929; Percent complete: 99.3%; Average loss: 1.1752
# Iteration: 9930; Percent complete: 99.3%; Average loss: 1.1961
# Iteration: 9931; Percent complete: 99.3%; Average loss: 1.3260
# Iteration: 9932; Percent complete: 99.3%; Average loss: 1.2265
# Iteration: 9933; Percent complete: 99.3%; Average loss: 1.3560
# Iteration: 9934; Percent complete: 99.3%; Average loss: 1.3285
# Iteration: 9935; Percent complete: 99.4%; Average loss: 1.3328
# Iteration: 9936; Percent complete: 99.4%; Average loss: 1.2306
# Iteration: 9937; Percent complete: 99.4%; Average loss: 1.2674
# Iteration: 9938; Percent complete: 99.4%; Average loss: 1.4272
# Iteration: 9939; Percent complete: 99.4%; Average loss: 1.2259
# Iteration: 9940; Percent complete: 99.4%; Average loss: 1.3100
# Iteration: 9941; Percent complete: 99.4%; Average loss: 1.2099
# Iteration: 9942; Percent complete: 99.4%; Average loss: 1.4010
# Iteration: 9943; Percent complete: 99.4%; Average loss: 1.2103
# Iteration: 9944; Percent complete: 99.4%; Average loss: 1.2256
# Iteration: 9945; Percent complete: 99.5%; Average loss: 1.3157
# Iteration: 9946; Percent complete: 99.5%; Average loss: 1.2173
# Iteration: 9947; Percent complete: 99.5%; Average loss: 1.2123
# Iteration: 9948; Percent complete: 99.5%; Average loss: 1.2630
# Iteration: 9949; Percent complete: 99.5%; Average loss: 1.5640
# Iteration: 9950; Percent complete: 99.5%; Average loss: 1.3503
# Iteration: 9951; Percent complete: 99.5%; Average loss: 1.3240
# Iteration: 9952; Percent complete: 99.5%; Average loss: 1.3069
# Iteration: 9953; Percent complete: 99.5%; Average loss: 1.3965
# Iteration: 9954; Percent complete: 99.5%; Average loss: 1.2017
# Iteration: 9955; Percent complete: 99.6%; Average loss: 1.2265
# Iteration: 9956; Percent complete: 99.6%; Average loss: 1.3337
# Iteration: 9957; Percent complete: 99.6%; Average loss: 1.2931
# Iteration: 9958; Percent complete: 99.6%; Average loss: 1.2297
# Iteration: 9959; Percent complete: 99.6%; Average loss: 1.3805
# Iteration: 9960; Percent complete: 99.6%; Average loss: 1.1946
# Iteration: 9961; Percent complete: 99.6%; Average loss: 1.3823
# Iteration: 9962; Percent complete: 99.6%; Average loss: 1.3586
# Iteration: 9963; Percent complete: 99.6%; Average loss: 1.2454
# Iteration: 9964; Percent complete: 99.6%; Average loss: 1.2812
# Iteration: 9965; Percent complete: 99.7%; Average loss: 1.2990
# Iteration: 9966; Percent complete: 99.7%; Average loss: 1.3784
# Iteration: 9967; Percent complete: 99.7%; Average loss: 1.2980
# Iteration: 9968; Percent complete: 99.7%; Average loss: 1.3781
# Iteration: 9969; Percent complete: 99.7%; Average loss: 1.2883
# Iteration: 9970; Percent complete: 99.7%; Average loss: 1.5333
# Iteration: 9971; Percent complete: 99.7%; Average loss: 1.3728
# Iteration: 9972; Percent complete: 99.7%; Average loss: 1.3002
# Iteration: 9973; Percent complete: 99.7%; Average loss: 1.3336
# Iteration: 9974; Percent complete: 99.7%; Average loss: 1.2432
# Iteration: 9975; Percent complete: 99.8%; Average loss: 1.4638
# Iteration: 9976; Percent complete: 99.8%; Average loss: 1.5358
# Iteration: 9977; Percent complete: 99.8%; Average loss: 1.3390
# Iteration: 9978; Percent complete: 99.8%; Average loss: 1.1979
# Iteration: 9979; Percent complete: 99.8%; Average loss: 1.4522
# Iteration: 9980; Percent complete: 99.8%; Average loss: 1.3462
# Iteration: 9981; Percent complete: 99.8%; Average loss: 1.2806
# Iteration: 9982; Percent complete: 99.8%; Average loss: 1.3430
# Iteration: 9983; Percent complete: 99.8%; Average loss: 1.2432
# Iteration: 9984; Percent complete: 99.8%; Average loss: 1.3051
# Iteration: 9985; Percent complete: 99.9%; Average loss: 1.3390
# Iteration: 9986; Percent complete: 99.9%; Average loss: 1.2561
# Iteration: 9987; Percent complete: 99.9%; Average loss: 1.2870
# Iteration: 9988; Percent complete: 99.9%; Average loss: 1.2960
# Iteration: 9989; Percent complete: 99.9%; Average loss: 1.5390
# Iteration: 9990; Percent complete: 99.9%; Average loss: 1.5768
# Iteration: 9991; Percent complete: 99.9%; Average loss: 1.3930
# Iteration: 9992; Percent complete: 99.9%; Average loss: 1.3074
# Iteration: 9993; Percent complete: 99.9%; Average loss: 1.4644
# Iteration: 9994; Percent complete: 99.9%; Average loss: 1.5277
# Iteration: 9995; Percent complete: 100.0%; Average loss: 1.2430
# Iteration: 9996; Percent complete: 100.0%; Average loss: 1.1351
# Iteration: 9997; Percent complete: 100.0%; Average loss: 1.2926
# Iteration: 9998; Percent complete: 100.0%; Average loss: 1.3590
# Iteration: 9999; Percent complete: 100.0%; Average loss: 1.4175
# Iteration: 10000; Percent complete: 100.0%; Average loss: 1.3689

# %%
encoder.eval()
decoder.eval()

searcher = GreedySearchDecoder(encoder, decoder)

evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > Hello
# Bot: hello . . . . .
# > Whats up dude
# Bot: huh ? huh ? ? .
# > whats up
# Bot: what ? . . . .
# > how are you?
# Bot: i m okay . . . .
# > do you speak english
# Bot: no . . . . .
# > what do you speek
# Error: Encountered unknown word.
# > what do you speak
# Bot: i m a different person now . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-a79dd57706ac> in <cell line: 9>()
#       7
#       8 # Begin chatting (uncomment and run the following line to begin)
# ----> 9 evaluateInput(encoder, decoder, searcher, voc)
#
# <ipython-input-17-7cdfa7345e53> in evaluateInput(encoder, decoder, searcher, voc)
#      22         try:
#      23             # Get input sentence
# ---> 24             input_sentence = input('> ')
#      25             # Check if it is quit case
#      26             if input_sentence == 'q' or input_sentence == 'quit': break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
ENCODER_PATH = '/content/drive/MyDrive/Colab Notebooks/Chatterbones/working/encoder.pt'

# %%
model_scripted = torch.jit.script(encoder) # Export to TorchScript
model_scripted.save('model_scripted.pt')
